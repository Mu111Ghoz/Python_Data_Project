# %%
# import libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date']   = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df=df[df['job_title_short']== 'Data Analyst']

df
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df_exploded = df.explode('job_skills')

skill_stats = df_exploded.groupby('job_skills').agg(
    skill_column=('job_skills', 'count'),
    median_salary=('salary_year_avg', 'median')
)

skill_stats = skill_stats.sort_values(by='skill_column', ascending=False).head(10)

skill_stats
# Out:
#             skill_column  median_salary
# job_skills
# sql                92428        92500.0
# excel              66860        84479.0
# python             57190        98500.0
# tableau            46455        95000.0
# power bi           39380        90000.0
# r                  29996        92527.5
# sas                27998        90000.0
# powerpoint         13822        85000.0
# word               13562        80000.0
# sap                11280        90000.0

# %%
skill_stats.plot(kind='scatter', x='skill_column', y='median_salary')
plt.title('Sallary vs. Count of Job Postings for Top 10 Skills')
plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary ($USD)')

for i, txt in enumerate(skill_stats.index):
    plt.text(skill_stats['skill_column'].iloc[i], skill_stats['median_salary'].iloc[i], txt, fontsize=9, ha='left', va='bottom')

plt.tight_layout()
plt.show()
